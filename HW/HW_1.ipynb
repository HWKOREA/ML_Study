# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt

cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, test_size = 0.2)
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)

plt.figure(figsize=(20, 10))
tree.plot_tree(clf, feature_names = cancer.feature_names.tolist(), class_names = [str(target) for target in cancer.target_names], filled=True)
# Out:
# [Text(0.7466517857142857, 0.9444444444444444, 'worst perimeter <= 114.45\ngini = 0.462\nsamples = 455\nvalue = [165, 290]\nclass = benign'),
#  Text(0.6004464285714286, 0.8333333333333334, 'worst concave points <= 0.146\ngini = 0.167\nsamples = 316\nvalue = [29, 287]\nclass = benign'),
#  Text(0.48660714285714285, 0.7222222222222222, 'worst radius <= 16.805\ngini = 0.09\nsamples = 296\nvalue = [14, 282]\nclass = benign'),
#  Text(0.36607142857142855, 0.6111111111111112, 'worst concave points <= 0.135\ngini = 0.055\nsamples = 284\nvalue = [8, 276]\nclass = benign'),
#  Text(0.23214285714285715, 0.5, 'area error <= 38.605\ngini = 0.029\nsamples = 271\nvalue = [4, 267]\nclass = benign'),
#  Text(0.14285714285714285, 0.3888888888888889, 'smoothness error <= 0.003\ngini = 0.015\nsamples = 261\nvalue = [2, 259]\nclass = benign'),
#  Text(0.07142857142857142, 0.2777777777777778, 'smoothness error <= 0.003\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = benign'),
#  Text(0.03571428571428571, 0.16666666666666666, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = benign'),
#  Text(0.10714285714285714, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = malignant'),
#  Text(0.21428571428571427, 0.2777777777777778, 'worst texture <= 33.27\ngini = 0.008\nsamples = 256\nvalue = [1, 255]\nclass = benign'),
#  Text(0.17857142857142858, 0.16666666666666666, 'gini = 0.0\nsamples = 240\nvalue = [0, 240]\nclass = benign'),
#  Text(0.25, 0.16666666666666666, 'worst texture <= 33.56\ngini = 0.117\nsamples = 16\nvalue = [1, 15]\nclass = benign'),
#  Text(0.21428571428571427, 0.05555555555555555, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = malignant'),
#  Text(0.2857142857142857, 0.05555555555555555, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]\nclass = benign'),
#  Text(0.32142857142857145, 0.3888888888888889, 'worst symmetry <= 0.207\ngini = 0.32\nsamples = 10\nvalue = [2, 8]\nclass = benign'),
#  Text(0.2857142857142857, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = malignant'),
#  Text(0.35714285714285715, 0.2777777777777778, 'radius error <= 0.421\ngini = 0.198\nsamples = 9\nvalue = [1, 8]\nclass = benign'),
#  Text(0.32142857142857145, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = malignant'),
#  Text(0.39285714285714285, 0.16666666666666666, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = benign'),
#  Text(0.5, 0.5, 'mean texture <= 20.24\ngini = 0.426\nsamples = 13\nvalue = [4, 9]\nclass = benign'),
#  Text(0.4642857142857143, 0.3888888888888889, 'worst symmetry <= 0.259\ngini = 0.18\nsamples = 10\nvalue = [1, 9]\nclass = benign'),
#  Text(0.42857142857142855, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = malignant'),
#  Text(0.5, 0.2777777777777778, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = benign'),
#  Text(0.5357142857142857, 0.3888888888888889, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = malignant'),
#  Text(0.6071428571428571, 0.6111111111111112, 'mean texture <= 18.975\ngini = 0.5\nsamples = 12\nvalue = [6, 6]\nclass = malignant'),
#  Text(0.5714285714285714, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = benign'),
#  Text(0.6428571428571429, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = malignant'),
#  Text(0.7142857142857143, 0.7222222222222222, 'mean smoothness <= 0.091\ngini = 0.375\nsamples = 20\nvalue = [15, 5]\nclass = malignant'),
#  Text(0.6785714285714286, 0.6111111111111112, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = benign'),
#  Text(0.75, 0.6111111111111112, 'worst texture <= 24.245\ngini = 0.208\nsamples = 17\nvalue = [15, 2]\nclass = malignant'),
#  Text(0.7142857142857143, 0.5, 'mean compactness <= 0.159\ngini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = benign'),
#  Text(0.6785714285714286, 0.3888888888888889, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = benign'),
#  Text(0.75, 0.3888888888888889, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = malignant'),
#  Text(0.7857142857142857, 0.5, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = malignant'),
#  Text(0.8928571428571429, 0.8333333333333334, 'worst concave points <= 0.095\ngini = 0.042\nsamples = 139\nvalue = [136, 3]\nclass = malignant'),
#  Text(0.8571428571428571, 0.7222222222222222, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = benign'),
#  Text(0.9285714285714286, 0.7222222222222222, 'mean concavity <= 0.056\ngini = 0.014\nsamples = 137\nvalue = [136, 1]\nclass = malignant'),
#  Text(0.8928571428571429, 0.6111111111111112, 'worst fractal dimension <= 0.077\ngini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = malignant'),
#  Text(0.8571428571428571, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = benign'),
#  Text(0.9285714285714286, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = malignant'),
#  Text(0.9642857142857143, 0.6111111111111112, 'gini = 0.0\nsamples = 135\nvalue = [135, 0]\nclass = malignant')]
